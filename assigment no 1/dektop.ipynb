# %%
import sys
print("system version")
print(sys.version)
print("version info")
print(sys.version_info)
# Out:
# system version
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# version info
# sys.version_info(major=3, minor=9, micro=7, releaselevel='final', serial=0)

# %%
import datetime
now =datetime.datetime.now()
print("current date and time is")
print(now.strftime("%y-%m-%d %H:%M:%S"))
# Out:
# current date and time is
# 21-12-31 21:07:03

# %%
from math import pi
r=float(input("write the radius of circle"))
print("the area of circle is"+ str(r) + "is: " +str(pi * r**2))
# Out:
# write the radius of circle3
# the area of circle is3.0is: 28.274333882308138

# %%
first_name = input(" write the first name")
last_name = input("write the last name")
print("Hello " + last_name + " "+ first_name )
# Out:
#  write the first nameumer
# write the last nameiqbal
# Hello iqbal umer

# %%
a="twinkle twinkle little star";
b="how i wonder what you are";
c="ub above the world so high";
d="like the diamond in the sky";
e=a+b+c+d;
print(e);
# Out:
# twinkle twinkle little starhow i wonder what you areub above the world so highlike the diamond in the sky
